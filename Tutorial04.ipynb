# %% [markdown]
# <a href="https://colab.research.google.com/github/hanifhidayatt/data-science-toolkit/blob/main/Tutorial04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/grandmaster07/student-exam-score-dataset-analysis")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: hanifhidayatt
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/grandmaster07/student-exam-score-dataset-analysis
# ...
# 100%|██████████| 2.37k/2.37k [00:00<00:00, 5.58MB/s]

# %%
import pandas as pd
data = pd.read_csv("/content/student-exam-score-dataset-analysis/student_exam_scores.csv")

# %%
data.head()
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3

# %%
data.shape
# Out:
# (200, 6)

# %%
print("Number of features:", data.shape[1])
print("Columns:", data.columns.tolist())
# Out:
# Number of features: 6
# Columns: ['student_id', 'hours_studied', 'sleep_hours', 'attendance_percent', 'previous_scores', 'exam_score']

# %%
print("Number of samples:", data.shape[0])
# Out:
# Number of samples: 200

# %%
data.dtypes
# Out:
# student_id             object
# hours_studied         float64
# sleep_hours           float64
# attendance_percent    float64
# previous_scores         int64
# exam_score            float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# student_id            0
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            0
# dtype: int64

# %%
data.isnull().any()
# Out:
# student_id            False
# hours_studied         False
# sleep_hours           False
# attendance_percent    False
# previous_scores       False
# exam_score            False
# dtype: bool

# %% [markdown]
# The questions can be answered by the outputs of the code. After analizing the datasets, there's a lot of questions that can be asked. One of them would be "Is there a correlation between attendance and exam performance?".
